# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions
from tensorflow.keras.models import Model
import numpy as np

# %%
modelo = VGG19()
# Out:
# ...
# 574726144/574710816 [==============================] - 7s 0us/step

# %%
#modelo.summary()

# %%
# !wget https://raw.githubusercontent.com/cardel/repositorios/main/imagen1.jpg
# !wget https://raw.githubusercontent.com/cardel/repositorios/main/imagen2.jpg
# Out:
# --2021-11-22 17:08:54--  https://raw.githubusercontent.com/cardel/repositorios/main/imagen1.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117465 (115K) [image/jpeg]
# Saving to: ‘imagen1.jpg’
#
# imagen1.jpg         100%[===================>] 114.71K  --.-KB/s    in 0.02s
#
# 2021-11-22 17:08:54 (5.49 MB/s) - ‘imagen1.jpg’ saved [117465/117465]
#
# --2021-11-22 17:08:54--  https://raw.githubusercontent.com/cardel/repositorios/main/imagen2.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
img = image.load_img("imagen2.jpg",target_size=(224,224))
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
predicion = modelo.predict(x)
print('Predecido:', decode_predictions(predicion, top=3)[0])
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# Predecido: [('n01518878', 'ostrich', 0.6600244), ('n01514668', 'cock', 0.09515974), ('n02012849', 'crane', 0.0709677)]
